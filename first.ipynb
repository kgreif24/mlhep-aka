# %% [markdown]
# <a href="https://colab.research.google.com/github/kgreif24/mlhep-aka/blob/restyled%2Fpull-11/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
! pip install qiskit

# %%
import qiskit

# %%
print(qiskit.version.get_version_info())
# Out:
# 1.2.4

# %%
from qiskit import *
# %matplotlib inline
circ = QuantumCircuit(2)
circ.h(0)
circ.cx(0,1)

# %%
circ.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘

# %%
from qiskit import *
from qiskit.visualization import plot_bloch_vector

# %%
plot_bloch_vector([0,0,1], title='spin_up')

# %%
qc = QuantumCircuit(1)
qc.x(0)

# %%
! pip install pylatexenc

# %%
qc.draw()
# Out:
#    ┌───┐
# q: ┤ X ├
#    └───┘

# %%
import matplotlib.pyplot as plt
qc.draw('mpl')

# %%
backend = Aer.get_backend('statevector_simulator')

output = execute(qc, backend).result().get_statevector()

print(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c015773bd1fb> in <cell line: 1>()
# ----> 1 backend = Aer.get_backend('statevector_simulator')
#       2
#       3 output = execute(qc, backend).result().get_statevector()
#       4
#       5 print(output)
#
# NameError: name 'Aer' is not defined
